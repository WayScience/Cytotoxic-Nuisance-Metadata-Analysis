# %%
import pandas as pd

# %%
df = pd.read_csv("../../../results/2.modeling/all_f1_scores.csv.gz")

# %%
df
# Out:
#      dataset_type  shuffled           injury_type  f1_score
# 0            Test     False               Control  0.793672
# 1            Test     False          Cytoskeletal  0.941725
# 2            Test     False                 Hsp90  0.843243
# 3            Test     False                Kinase  0.676385
# 4            Test     False             Genotoxin  0.680162
# ..            ...       ...                   ...       ...
# 155  Well Holdout      True          Mitochondria  0.000000
# 156  Well Holdout      True           Ferroptosis  0.000000
# 157  Well Holdout      True                Tannin  0.000000
# 158  Well Holdout      True  Nonspecific reactive  0.000000
# 159  Well Holdout      True              weighted  0.021274
#
# [160 rows x 4 columns]

# %%
df.dataset_type.unique()
# Out:
# array(['Test', 'Train', 'Plate Holdout', 'Treatment Holdout',
#        'Well Holdout'], dtype=object)

# %%
df.loc[df.dataset_type == "Treatment Holdout"]
# Out:
#           dataset_type  shuffled           injury_type  f1_score
# 96   Treatment Holdout     False               Control  0.000000
# 97   Treatment Holdout     False          Cytoskeletal  0.000000
# 98   Treatment Holdout     False                 Hsp90  0.000000
# 99   Treatment Holdout     False                Kinase  0.000000
# 100  Treatment Holdout     False             Genotoxin  1.000000
# 101  Treatment Holdout     False         Miscellaneous  0.080000
# 102  Treatment Holdout     False                 Redox  0.555556
# 103  Treatment Holdout     False                  HDAC  0.000000
# 104  Treatment Holdout     False                  mTOR  0.000000
# 105  Treatment Holdout     False            Proteasome  0.000000
# 106  Treatment Holdout     False               Saponin  0.476190
# 107  Treatment Holdout     False          Mitochondria  0.000000
# 108  Treatment Holdout     False           Ferroptosis  0.000000
# 109  Treatment Holdout     False                Tannin  0.000000
# 110  Treatment Holdout     False  Nonspecific reactive  0.000000
# 111  Treatment Holdout     False              weighted  0.543553
# 112  Treatment Holdout      True               Control  0.000000
# 113  Treatment Holdout      True          Cytoskeletal  0.000000
# 114  Treatment Holdout      True                 Hsp90  0.000000
# 115  Treatment Holdout      True                Kinase  0.000000
# 116  Treatment Holdout      True             Genotoxin  0.578313
# 117  Treatment Holdout      True         Miscellaneous  0.480000
# 118  Treatment Holdout      True                 Redox  0.000000
# 119  Treatment Holdout      True                  HDAC  0.000000
# 120  Treatment Holdout      True                  mTOR  0.000000
# 121  Treatment Holdout      True            Proteasome  0.000000
# 122  Treatment Holdout      True               Saponin  0.000000
# 123  Treatment Holdout      True          Mitochondria  0.000000
# 124  Treatment Holdout      True           Ferroptosis  0.000000
# 125  Treatment Holdout      True                Tannin  0.000000
# 126  Treatment Holdout      True  Nonspecific reactive  0.000000
# 127  Treatment Holdout      True              weighted  0.288881
