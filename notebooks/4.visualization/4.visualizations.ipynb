# %%
proba_file <- file.path("../../results/3.jump_analysis/JUMP_injury_proba.csv.gz")

# %%
data <- read.csv(proba_file)

# %%
data
# Out:
#       X     Metadata_broad_sample  Metadata_Plate Metadata_Well Metadata_gene
# 1      0    BRDN0001480888         BR00116997     A01           HIF1A
# 2      1    BRDN0001483495         BR00116997     A02           CATSPER4
# 3      2    BRDN0001147364         BR00116997     A03           DDR2
# 4      3    BRDN0001490272         BR00116997     A04           OPRL1
# 5      4    BRDN0001480510         BR00116997     A05           SLC7A11
# 6      5    BRDN0001487636         BR00116997     A06           FFAR2
# 7      6    BRDN0001484752         BR00116997     A07           KCNMA1
# 8      7    BRDN0001485022         BR00116997     A08           HRH4
# 9      8    BRDN0001488469         BR00116997     A09           GHSR
# 10     9    BRDN0001479055         BR00116997     A10           ALDH2
# 11    10    BRDN0001488387         BR00116997     A11           OPRL1
# 12    11    BRDN0001487915         BR00116997     A12           COMT
# ...
