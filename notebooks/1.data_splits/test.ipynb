# %%
import sys
import pandas as pd

sys.path.append("../../")
from src import utils

# %%
df = pd.read_csv("../../results/0.feature_selection/fs_cell_injury_only.csv.gz")

# %%
meta, feats = utils.split_meta_and_features(df)

# %%
df = df[feats]

# %%
df[df.isna().any(axis=1)]
# Out:
#        Cells_AreaShape_Area  Cells_AreaShape_Center_Y  \
# 14197                   NaN                       NaN
# 14986                   NaN                       NaN
#
#        Cells_AreaShape_Compactness  Cells_AreaShape_FormFactor  \
# 14197                          NaN                         NaN
# 14986                          NaN                         NaN
#
#        Cells_AreaShape_Orientation  Cells_AreaShape_Perimeter  \
# 14197                          NaN                        NaN
# 14986                          NaN                        NaN
#
#        Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_1_1  \
# 14197                       NaN                          NaN
# 14986                       NaN                          NaN
#
#        Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_2_2  ...  \
# 14197                          NaN                          NaN  ...
# 14986                          NaN                          NaN  ...
#
# ...

# %%
df = pd.read_csv("../../data/idr0133-screenA-annotation.csv.gz")
df.shape
# Out:
# (23111, 403)

# %%
df = df[feats]
df[df.isna().any(axis=1)]
# Out:
#        Cells_AreaShape_Area  Cells_AreaShape_Center_Y  \
# 1686                    NaN                       NaN
# 6308                    NaN                       NaN
# 20550                   NaN                       NaN
#
#        Cells_AreaShape_Compactness  Cells_AreaShape_FormFactor  \
# 1686                           NaN                         NaN
# 6308                           NaN                         NaN
# 20550                          NaN                         NaN
#
#        Cells_AreaShape_Orientation  Cells_AreaShape_Perimeter  \
# 1686                           NaN                        NaN
# 6308                           NaN                        NaN
# 20550                          NaN                        NaN
#
#        Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_1_1  \
# 1686                        NaN                          NaN
# 6308                        NaN                          NaN
# ...

# %%
df2 = df.dropna()

# %%
df.shape[0] - df2.shape[0]
# Out:
# 3
